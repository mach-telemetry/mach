# %%
import matplotlib.pyplot as plt
plt.rc('font', size=13)
plt.rcParams['font.family'] = 'serif'

requests = [1, 2, 4, 8, 16, 26, 27, 28, 29, 30, 31, 32]
ticks = [1, 2, 4, 8, 16, 32]
completeness = [100, 100, 100,100 ,100, 99, 94, 93, 91, 90, 90, 89 ]

plt.figure(figsize=(6, 2))
ax = plt.axes()
ax.set_ylim([0, 110])
#ax.set_xlim([1, 32])
ax.set_xlabel("Snapshotting Threads")
ax.set_xticks(ticks, ticks)
ax.set_ylabel("Completeness\n(%)")
ax.plot(requests, completeness)
plt.tight_layout(pad=1)
plt.savefig('evaluation-snapshotting.pdf')
